# %% [markdown]
# <a href="https://colab.research.google.com/github/rb58853/ML-RSI-Images/blob/main/code/datasets/get_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## mount drive

# %%
pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login
login(token="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")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import Dataset, load_dataset
dataset = load_dataset("rb58853/caption_image", split = 'train')

# %%
import matplotlib.pyplot as plt
LEN = 10
INDEX = 0
print (dataset)
for image, text in zip(dataset['image'],dataset['caption']):
    INDEX+=1
    if INDEX > LEN: break
    plt.figure(figsize=(2,2))
    plt.title(text)
    plt.imshow(image)
    plt.axis('off')
    plt.show()
# Out:
# Dataset({
#     features: ['image', 'caption'],
#     num_rows: 5
# })
